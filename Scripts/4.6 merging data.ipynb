# %%
import pandas as pd
import numpy as nd
import os

# %%
path = r'C:\Users\Nbdav\Instacart Basket Analysis'

# %%
 = pd.read_csv(r'C:\Users\Nbdav\Instacart Basket Analysis\02 Data\order_products__prior.csv', index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 data', 'orders.csv'), index_col = False)

# %%
df_ords_cleaned = pd.read_csv(os.path.join(path, '02 data', 'Prepared data', 'orders_cleaned.csv'), index_col = False)

# %%
df_prods_cleaned = pd.read_csv(os.path.join(path, '02 data',  'Prepared data', 'products_cleaned.csv'), index_col = False)

# %%
#check output of data
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
#merging two data frames on the order_id
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # combining cleaned ords and cleaned prods data set

# %%
#merging ords cleaned with ords prior
df_merged_ords = df_ords_cleaned.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_ords
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  0   2539329        1    prior             1          2
# 2                  0   2539329        1    prior             1          2
# 3                  0   2539329        1    prior             1          2
# 4                  0   2539329        1    prior             1          2
# ...              ...       ...      ...      ...           ...        ...
# 32434484     3421081   2977660   206209    prior            13          1
# 32434485     3421081   2977660   206209    prior            13          1
# 32434486     3421081   2977660   206209    prior            13          1
# 32434487     3421081   2977660   206209    prior            13          1
# 32434488     3421081   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  ordered_today  \
# ...

# %%
df_merged_ords.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_cleaned_products_combined.pkl'))

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_cleaned.shape
# Out:
# (3421083, 9)

# %%
#merging pords cleaned with ords prior
df_merged_prods = df_prods_cleaned.merge(df_ords_prior, on = 'product_id', indicator = True)

# %%
df_merged_prods
# Out:
#           Unnamed: 0  product_id                product_name  aisle_id  \
# 0                  0           1  Chocolate Sandwich Cookies        61
# 1                  0           1  Chocolate Sandwich Cookies        61
# 2                  0           1  Chocolate Sandwich Cookies        61
# 3                  0           1  Chocolate Sandwich Cookies        61
# 4                  0           1  Chocolate Sandwich Cookies        61
# ...              ...         ...                         ...       ...
# 32404854       49692       49688      Fresh Foaming Cleanser        73
# 32404855       49692       49688      Fresh Foaming Cleanser        73
# 32404856       49692       49688      Fresh Foaming Cleanser        73
# 32404857       49692       49688      Fresh Foaming Cleanser        73
# 32404858       49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  add_to_cart_order  reordered _merge
# ...

# %%
df_merged_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'products_cleaned_products_combined.pkl'))
