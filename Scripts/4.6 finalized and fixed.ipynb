# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Nbdav\Instacart Basket Analysis'

# %%
df_prods_cleaned = pd.read_csv(os.path.join(path, '02 data',  'Prepared data', 'products_cleaned.csv'), index_col = False)

# %%
df_ords_products_merged = pd.read_pickle(os.path.join(path, '02 data', 'Prepared data','orders_cleaned_products_combined.pkl'))

# %%
df_prods_cleaned = df_prods_cleaned.drop(columns = ['Unnamed: 0',])

# %%
df_prods_cleaned
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_ords_products_merged = df_ords_products_merged.drop(columns = ['_merge','Unnamed: 0'])

# %%
#find way to merge columns products on order/orders_prior
df_ords_products_combined = df_ords_products_merged.merge(df_prods_cleaned, on = ['product_id'], how = 'left',indicator = True)

# %%
df_prods_cleaned
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_ords_products_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32435054   2977660   206209    prior            13          1
# 32435055   2977660   206209    prior            13          1
# 32435056   2977660   206209    prior            13          1
# 32435057   2977660   206209    prior            13          1
# 32435058   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  ordered_today  \
# 0                         8                     NaN           True
# 1                         8                     NaN           True
# ...

# %%
df_ords_products_combined.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_final.pkl'))
